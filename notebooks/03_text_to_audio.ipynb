# %%
# !pip install openai python-dotenv -q

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Audio, display

# %%
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

print("API key loaded")
# Out:
# API key loaded

# %%
text = """
Hello ETHIOPIA PEOPLE. Welcome to your Text to Audio project.
This notebook converts written text into spoken audio using OpenAI.
"""

# %%
audio_file = "text_to_audio.mp3"

with client.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice="alloy",
    input=text,
) as response:
    response.stream_to_file(audio_file)

print("Audio created successfully")
# Out:
# Audio created successfully

# %%
display(Audio(audio_file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
